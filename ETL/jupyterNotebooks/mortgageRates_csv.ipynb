# %%
import pandas as pd

# read the csv file and store it in a variable called 'data'
mortgage_df = pd.read_csv('../../data/housinglending.csv')

# display the first few rows of the data
mortgage_df.head()
# Out:
#      col_name  Rates,OO ,Banks  Rates,OO , All institutions  \
# 0  31/07/2019             3.83                         3.84
# 1  31/08/2019             3.81                         3.82
# 2  30/09/2019             3.78                         3.79
# 3  31/10/2019             3.68                         3.69
# 4  30/11/2019             3.67                         3.67
#
#    Rates,OO,Var, Banks  Rates,OO,Var, Banks.1  Rates,OO,Fixed =<3 years  \
# 0                 3.80                   3.81                      3.94
# 1                 3.78                   3.79                      3.91
# 2                 3.76                   3.77                      3.89
# 3                 3.64                   3.64                      3.87
# 4                 3.63                   3.63                      3.83
#
#    Rates,OO,Fixed =>3 years  Rates,OO,Interest Only  Rates,OO,P&I   \
# 0                      4.35                    4.31           3.77
# 1                      4.28                    4.35           3.75
# 2                      4.26                    4.32           3.73
# 3                      4.20                    4.29           3.61
# 4                      4.10                    4.27           3.59
#
#    Rates,New Loan, OO,All Loans, Banks  ...  \
# 0                                 3.52  ...
# 1                                 3.47  ...
# 2                                 3.44  ...
# 3                                 3.29  ...
# 4                                 3.27  ...
#
#    Rates,New Loans, Investment Loan, Variable, All Institutions   \
# 0                                               3.90
# 1                                               3.92
# 2                                               3.90
# 3                                               3.71
# 4                                               3.69
#
#    Rates,New Loans, Investment Loan,Fixed=<3 years  \
# 0                                             3.81
# 1                                             3.69
# 2                                             3.65
# 3                                             3.49
# 4                                             3.41
#
#    Rates,New Loans, Investment Loan,Fixed=>3 years  \
# 0                                             4.15
# 1                                             4.15
# 2                                             3.90
# 3                                             3.79
# 4                                             3.68
#
#    Rates,New Loans, Investment, Interest Only  \
# 0                                        4.16
# 1                                        4.08
# 2                                        4.05
# 3                                        3.86
# 4                                        3.84
#
#    Rates,New Loans, Investment, P&I Only  \
# 0                                   3.79
# 1                                   3.77
# 2                                   3.73
# 3                                   3.57
# 4                                   3.54
#
#    Rates,New Loans, Investment, LVR=<81%  \
# 0                                   3.88
# 1                                   3.88
# 2                                   3.85
# 3                                   3.68
# 4                                   3.65
#
#    Rates,New Loans, Investment, LVR=>81%  \
# 0                                   3.96
# 1                                   3.92
# 2                                   3.89
# 3                                   3.73
# 4                                   3.68
#
#    Rates,New Loans, Investment,                      Price =< $600K  \
# 0                                               3.87
# 1                                               3.88
# 2                                               3.85
# 3                                               3.68
# 4                                               3.66
#
#    Rates,New Loans, Investment,                       Price = $600K - $1million  \
# 0                                               3.92
# 1                                               3.88
# 2                                               3.86
# 3                                               3.70
# 4                                               3.66
#
#    Rates,New Loans, Investment,                       Price => $1million
# 0                                               3.92
# 1                                               3.91
# 2                                               3.88
# 3                                               3.68
# 4                                               3.64
#
# [5 rows x 43 columns]

# %%
# Select just the first two columns
mortgage_df = mortgage_df.iloc[:, :2]
# Rename the columns
mortgage_df.columns = ['date', 'mortgage_rate']
# Change the date format
mortgage_df['date'] = pd.to_datetime(mortgage_df['date'], format='%d/%m/%Y').dt.strftime('%Y-%m-%d')
mortgage_df.head()
# Out:
#          date  mortgage_rate
# 0  2019-07-31           3.83
# 1  2019-08-31           3.81
# 2  2019-09-30           3.78
# 3  2019-10-31           3.68
# 4  2019-11-30           3.67
